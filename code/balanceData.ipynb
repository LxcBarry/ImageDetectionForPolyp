# %%
"""count the label img and unlabel img"""
import numpy as np
import matplotlib.pyplot as plt
import os
import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\19798\Desktop\record\balanceData.py in <module>
#       <a href='file://c:\Users\19798\Desktop\record\balanceData.py?line=1'>2</a> """count the label img and unlabel img"""
#       <a href='file://c:\Users\19798\Desktop\record\balanceData.py?line=2'>3</a> import numpy as np
# ----> <a href='file://c:\Users\19798\Desktop\record\balanceData.py?line=3'>4</a> import matplotlib.pyplot as plt
#       <a href='file://c:\Users\19798\Desktop\record\balanceData.py?line=4'>5</a> import os
#       <a href='file://c:\Users\19798\Desktop\record\balanceData.py?line=5'>6</a> import random
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
"""count the label img and unlabel img"""
import numpy as np
import matplotlib.pyplot as plt
import os
import random

# %%
img_path = "image_train"
label_path = "labels_train"
test_img_path = "test_images"
train_img_path = "train_images"
img_files = os.listdir(img_path)

label_imgs = [f for f in img_files if os.path.exists(f"{label_path}/{f[:-4]}.txt")]
unlabel_imgs = [f for f in img_files if not os.path.exists(f"{label_path}/{f[:-4]}.txt")]

plt.bar(['labeled','nonlabeled'],[len(label_imgs),len(unlabel_imgs)])
plt.title('data distribution')
# label:857, nonlabel:643
# Out:
# Text(0.5, 1.0, 'data distribution')

# %%
# 8:2(or other choise)split data,mixed with both label-images and nonlabel-images

partial=(0.8,0.2)
# shuffle data
random.shuffle(label_imgs)
random.shuffle(unlabel_imgs)
train_imgs = label_imgs[:int(0.8*len(label_imgs))]+unlabel_imgs[:int(0.8*len(unlabel_imgs))]
test_imgs = label_imgs[int(0.8*len(label_imgs)):]+unlabel_imgs[int(0.8*len(unlabel_imgs)):]

# %%
if not os.path.exists(train_img_path):
    os.mkdir(train_img_path)
if not os.path.exists(test_img_path):
    os.mkdir(test_img_path)

for file in train_imgs:
    os.popen(f'cp {img_path}/{file} {train_img_path}/{file}')
for file in test_img_path:
    os.popen(f'cp {img_path}/{file} {test_img_path}/{file}')
