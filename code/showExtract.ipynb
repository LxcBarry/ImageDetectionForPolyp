# %%
from showLabelImg import *
from extractImg import *
# %matplotlib inline

# %%
# 数据预处理
# 1. 提取80-140之间的像素(图片分层),这里希望能够在报告中做图片对比，目前测试的文件夹是'test',输出文件夹是'extract_out'
extractFeatures((80,180),show=True)

# %%
# !mkdir one_plues_two
# Out:
# ��Ŀ¼���ļ� one_plues_two �Ѿ����ڡ�

# %%
# 2. 直方图均衡化(报告中讲讲)，增加对比度
transferImgs(test_dir='extract_out',out_dir='one_plues_two',show=True)

# %% [markdown]
# **数据预处理就做这两步，第二步属于图片增强,下面把方框画到图片上面看看**

# %%
labelImg("one_plues_two",show=True)
